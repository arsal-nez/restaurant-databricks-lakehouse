# %%
# %sql

SELECT COUNT(*) AS customer_count
FROM restaurant_lakehouse.bronze.customers;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_count</th></tr></thead><tbody><tr><td>500</td></tr></tbody></table></div>

# %%
restaurants_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv(
        "/Volumes/restaurant_lakehouse/landing/restaurant_files/restaurants.csv"
    )
)

display(restaurants_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>restaurant_id</th><th>name</th><th>city</th><th>country</th><th>address</th><th>opening_date</th><th>phone</th></tr></thead><tbody><tr><td>REST-AUH-001</td><td>Spice Route Downtown</td><td>Abu Dhabi</td><td>UAE</td><td>Corniche Road Abu Dhabi</td><td>2023-01-15</td><td>+971-2-123-4567</td></tr><tr><td>REST-AUH-002</td><td>Spice Route Al Wahda</td><td>Abu Dhabi</td><td>UAE</td><td>Al Wahda Mall Abu Dhabi</td><td>2023-06-20</td><td>+971-2-234-5678</td></tr><tr><td>REST-DXB-001</td><td>Spice Route Marina</td><td>Dubai</td><td>UAE</td><td>Dubai Marina Walk</td><td>2023-03-10</td><td>+971-4-345-6789</td></tr><tr><td>REST-DXB-002</td><td>Spice Route Mall of Emirates</td><td>Dubai</td><td>UAE</td><td>Mall of the Emirates Dubai</td><td>2023-09-05</td><td>+971-4-456-7890</td></tr><tr><td>REST-SHJ-001</td><td>Spice Route City Centre</td><td>Sharjah</td><td>UAE</td><td>City Centre Sharjah</td><td>2024-02-14</td><td>+971-6-567-8901</td></tr></tbody></table></div>

# %%
restaurants_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv(
        "/Volumes/restaurant_lakehouse/landing/restaurant_files/restaurants.csv"
    )
)

display(restaurants_df)
(
    restaurants_df.write
    .format("delta")
    .mode("overwrite")
    .saveAsTable(
        "restaurant_lakehouse.bronze.restaurants"
    )
)
menu_items_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv(
        "/Volumes/restaurant_lakehouse/landing/restaurant_files/menu_items.csv"
    )
)

display(menu_items_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>restaurant_id</th><th>name</th><th>city</th><th>country</th><th>address</th><th>opening_date</th><th>phone</th></tr></thead><tbody><tr><td>REST-AUH-001</td><td>Spice Route Downtown</td><td>Abu Dhabi</td><td>UAE</td><td>Corniche Road Abu Dhabi</td><td>2023-01-15</td><td>+971-2-123-4567</td></tr><tr><td>REST-AUH-002</td><td>Spice Route Al Wahda</td><td>Abu Dhabi</td><td>UAE</td><td>Al Wahda Mall Abu Dhabi</td><td>2023-06-20</td><td>+971-2-234-5678</td></tr><tr><td>REST-DXB-001</td><td>Spice Route Marina</td><td>Dubai</td><td>UAE</td><td>Dubai Marina Walk</td><td>2023-03-10</td><td>+971-4-345-6789</td></tr><tr><td>REST-DXB-002</td><td>Spice Route Mall of Emirates</td><td>Dubai</td><td>UAE</td><td>Mall of the Emirates Dubai</td><td>2023-09-05</td><td>+971-4-456-7890</td></tr><tr><td>REST-SHJ-001</td><td>Spice Route City Centre</td><td>Sharjah</td><td>UAE</td><td>City Centre Sharjah</td><td>2024-02-14</td><td>+971-6-567-8901</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>restaurant_id</th><th>item_id</th><th>name</th><th>category</th><th>price</th><th>ingredients</th><th>is_vegetarian</th><th>spice_level</th></tr></thead><tbody><tr><td>REST-AUH-001</td><td>ITEM-101</td><td>Samosa (2 pcs)</td><td>Starter</td><td>17.52</td><td>Potato, Peas, Spices, Pastry</td><td>true</td><td>Medium</td></tr><tr><td>REST-AUH-001</td><td>ITEM
df.write
    .format("delta")
    .mode("overwrite")
    .saveAsTable(
        "restaurant_lakehouse.bronze.menu_items"
    )
)

# %%
display(
    dbutils.fs.ls(
        "/Volumes/restaurant_lakehouse/landing/restaurant_files/"
    )
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/restaurant_lakehouse/landing/restaurant_files/customer_reviews.csv</td><td>customer_reviews.csv</td><td>19156</td><td>1784845481000</td></tr><tr><td>dbfs:/Volumes/restaurant_lakehouse/landing/restaurant_files/customers.csv</td><td>customers.csv</td><td>39498</td><td>1784843791000</td></tr><tr><td>dbfs:/Volumes/restaurant_lakehouse/landing/restaurant_files/historical_orders.csv</td><td>historical_orders.csv</td><td>4600194</td><td>1784845454000</td></tr><tr><td>dbfs:/Volumes/restaurant_lakehouse/landing/restaurant_files/menu_items.csv</td><td>menu_items.csv</td><td>13599</td><td>1784844979000</td></tr><tr><td>dbfs:/Volumes/restaurant_lakehouse/landing/restaurant_files/restaurants.csv</td><td>restaurants.csv</td><td>552</td><td>1784844959000</td></tr></tbody></table></div>

# %%
customer_reviews_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv(
        "/Volumes/restaurant_lakehouse/landing/restaurant_files/customer_reviews.csv"
    )
)

display(customer_reviews_df)
(
    customer_reviews_df.write
    .format("delta")
    .mode("overwrite")
    .saveAsTable(
        "restaurant_lakehouse.bronze.reviews"
    )
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>review_id</th><th>order_id</th><th>customer_id</th><th>restaurant_id</th><th>review_text</th><th>rating</th><th>review_timestamp</th></tr></thead><tbody><tr><td>REV-000001</td><td>ORD-20260125-378532</td><td>CUST-10250</td><td>REST-AUH-002</td><td>Absolutely amazing Masala Chai  Garlic Naan  Gajar Halwa  and Tandoori Roti! The Tandoori Roti was cooked to perfection. Fresh ingredients and authentic flavors. Highly recommend!</td><td>5</td><td>2026-01-26T12:15:51.393Z</td></tr><tr><td>REV-000003</td><td>ORD-20260129-811077</td><td>CUST-10036</td><td>REST-DXB-002</td><td>Incredible meal! Samosa (2 pcs)  Naan  Paneer Tikka  Dal Makhani  and Tandoori Roti arrived hot and fresh. The Samosa (2 pcs) was absolutely divine. Highly satisfied!</td><td>5</td><td>2026-01-30T11:24:04.393Z</td></tr><tr><td>REV-000002</td><td>ORD-20260128-491532</td><td>CUST-10395</td><td>REST-AUH-001</td><td>Solid experience. Jeera Rice were well-prepared. Jeera Rice had great flavor. Minor issues with packaging.</td><td>4</td><td>2026-01-31T18:29:21.393Z</td></tr><tr><td>REV-000004</td><td>ORD-20260129-392977</td><td>CUST-10358</td><td>REST-AUH-001</td><td>Wow! Just wow! Malai Kofta  Garlic Naan  Samosa (2 pcs)  Aloo Tikki Chaat  and Chicken Biryani were all fantastic. Malai Kofta was particularly memorable. Can't wait to order again!</td><td>5</td><td>2026-02-03T16:06:30.393Z</td></tr><tr><td>REV-000006</td><td>ORD-20260204-856133</td><td>CUST-10459</td><td>REST-AUH-002</td><td>Incredible meal! Naan and Malai Kofta arrived hot and fresh. The Naan was absolutely divine. Highly satisfied!</td><td>5</td><td>2026-02-05T14:54:26.393Z</td></tr><tr><td>REV-000008</td><td>ORD-20260205-589115</td><td>CUST-10312</td><td>REST-AUH-001</td><td>Enjoyed the Mango Lassi  Chole Bhature  and Malai Kofta! Malai Kofta was very good. Portion sizes were generous. Recommend!</td><td>4</td><td>2026-02-07T13:31:49.393Z</td></tr><tr><td>REV-000010</td><td>ORD-20260206-690392</td><td>CUST-10411</td><td>REST-DXB-001</td><td>It was okay. Gulab Jamun (2 pcs)  Fish Curry  Masala Chai  Palak Paneer  and Rasmalai (2 pcs) arrived lukewarm. Masala Chai tasted fine but could be better.</td><td>3</td><td>2026-02-07T22:02:51.393Z</td></tr><tr><td>REV-000005</td><td>ORD-20260131-686336</td><td>CUST-10476</td><td>REST-AUH-001</td><td>Perfect in every way! Fresh Lime Soda  Palak Paneer  Butter Naan  Lamb Rogan Josh  and Chicken Tikka Masala were all excellent. Butter Naan stood out with its rich  authentic taste.</td><td>5</td><td>2026-02-07T22:56:49.393Z</td></tr><tr><td>REV-000007</td><td>ORD-20260205-161073</td><td>CUST-10300</td><td>REST-AUH-001</td><td>Average experience. Rasmalai (2 pcs)  Lamb Rogan Josh  and Chicken Biryani were fine but Lamb Rogan Josh was a bit bland. Room for improvement.</td><td>3</td><td>2026-02-10T13:23:59.393Z</td></tr><tr><td>REV-000009</td><td>ORD-20260205-876293</td><td>CUST-10016</td><td>REST-DXB-001</td><td>Below expectations. Butter Chicken and Gulab Jamun (2 pcs) were underwhelming. Butter Chicken was overcooked and dry.</td><td>2</td><td>2026-02-12T17:13:54.393Z</td></tr><tr><td>REV-000011</td><td>ORD-20260208-655908</td><td>CUST-10333</td><td>REST-DXB-001</td><td>Good quality food. Chicken 65  Jeera Rice  Malai Kofta  and Rasmalai (2 pcs) were nicely done. Jeera Rice could have been slightly spicier but still good!</td><td>4</td><td>2026-02-13T19:31:11.393Z</td></tr><tr><td>REV-000013</td><td>ORD-20260215-242409</td><td>CUST-10135</td><td>REST-SHJ-001</td><td>Incredible meal! Naan and Butter Chicken arrived hot and fresh. The Butter Chicken was absolutely divine. Highly satisfied!</td><td>5</td><td>2026-02-16T18:23:17.393Z</td></tr><tr><td>REV-000014</td><td>ORD-20260216-460104</td><td>CUST-10318</td><td>REST-AUH-002</td><td>Pleasant meal! Samosa (2 pcs)  Paneer Tikka  Butter Chicken  and Chole Bhature arrived warm. Samosa (2 pcs) was tasty  ...

# %%
tables = [
    "customers",
    "restaurants",
    "menu_items",
    "historical_orders",
    "reviews"
]

for table in tables:
    print("\n" + "=" * 60)
    print(f"TABLE: {table}")
    print("=" * 60)

    df = spark.table(f"restaurant_lakehouse.bronze.{table}")
    df.printSchema()
# Out:
# ============================================================
# TABLE: customers
# ============================================================
# root
#  |-- customer_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- phone: long (nullable = true)
#  |-- city: string (nullable = true)
#  |-- join_date: date (nullable = true)
#
#
# ============================================================
# TABLE: restaurants
# ============================================================
# root
#  |-- restaurant_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- opening_date: date (nullable = true)
#  |-- phone: string (nullable = true)
#
#
# ============================================================
# TABLE: menu_items
# ============================================================
# root
#  |-- restaurant_id: string (nullable = true)
#  |-- item_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- price: double (nullable = true)
#  |-- ingredients: string (nullable = true)
#  |-- is_vegetarian: boolean (nullable = true)
#  |-- spice_level: string (nullable = true)
#
#
# ============================================================
# TABLE: historical_orders
# ============================================================
# root
#  |-- order_id: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- restaurant_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- order_type: string (nullable = true)
#  |-- items: string (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- payment_method: string (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- created_at: timestamp (nullable = true)
#
#
# ============================================================
# TABLE: reviews
# ============================================================
# root
#  |-- review_id: string (nullable = true)
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- restaurant_id: string (nullable = true)
#  |-- review_text: string (nullable = true)
#  |-- rating: integer (nullable = true)
#  |-- review_timestamp: timestamp (nullable = true)

# %%
historical_orders_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .option("quote", '"')
    .option("escape", '"')
    .option("multiLine", "true")
    .option("mode", "PERMISSIVE")
    .csv(
        "/Volumes/restaurant_lakehouse/landing/restaurant_files/historical_orders.csv"
    )
)

# %%
(
    historical_orders_df.write
    .format("delta")
    .mode("overwrite")
    .option("overwriteSchema", "true")
    .saveAsTable(
        "restaurant_lakehouse.bronze.historical_orders"
    )
)

# %%
base_path = "/Volumes/restaurant_lakehouse/landing/restaurant_files/"

# %%
customers_path = base_path + "customers.csv"
restaurants_path = base_path + "restaurants.csv"
menu_items_path = base_path + "menu_items.csv"
orders_path = base_path + "historical_orders.csv"
reviews_path = base_path + "customer_reviews.csv"

# %%
orders_check = spark.table(
    "restaurant_lakehouse.bronze.historical_orders"
)

orders_check.select(
    "order_id",
    "items",
    "total_amount"
).show(2, truncate=False)
# Out:
# +-------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+
# |order_id           |items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |total_amount|
# +-------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+
# |ORD-20260125-880072|[{"item_id": "ITEM-103", "name": "Chicken 65", "category": "Starter", "quantity": 2, "unit_price": 38.24, "subtotal": 76.48}, {"item_id": "ITEM-102", "name": "Paneer Tikka", "category": "Starter", "quantity": 3, "unit_price": 36.48, "subtotal": 109.44}, {"item_id": "ITEM-502", "name": "Rasmalai (2 pcs)", "category": "Dessert", "quantity": 1, "unit_price": 17.5, "subtotal": 17.5}, {"item_id": "ITEM-303", "name": "Lamb Rogan Josh", "category": "Main Course", "quantity": 2, "unit_price": 61.83, "subtotal": 123.66}]|327.08      |
# |ORD-20260125-142045|[{"item_id": "ITEM-102", "name": "Paneer Tikka", "category": "Starter", "quantity": 2, "unit_price": 33.54, "subtotal": 67.08}, {"item_id": "ITEM-202", "name": "Dal Makhani", "category": "Main Course", "quantity": 2, "unit_price": 39.34, "subtotal": 78.68}, {"item_id": "ITEM-601", "name": "Masala Chai", "category": "Beverage", "quantity": 3, "unit_price": 11.54, "subtotal": 34.62}, {"item_id": "ITEM-405", "name": "Jeera Rice", "category": "Rice", "quantity": 2, "unit_price": 17.89, "subtotal": 35.78}]           |216.16      |
# +-------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+
# only showing top 2 rows

# %%
historical_orders_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .option("quote", '"')
    .option("escape", '"')
    .option("multiLine", "true")
    .option("mode", "PERMISSIVE")
    .csv(
        "/Volumes/restaurant_lakehouse/landing/restaurant_files/historical_orders.csv"
    )
)

# %%
print("Historical orders:", historical_orders_df.count())

historical_orders_df.printSchema()
# Out:
# Historical orders: 8000
# root
#  |-- order_id: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- restaurant_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- order_type: string (nullable = true)
#  |-- items: string (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- payment_method: string (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- created_at: timestamp (nullable = true)

# %%
(
    historical_orders_df.write
    .format("delta")
    .mode("overwrite")
    .option("overwriteSchema", "true")
    .saveAsTable(
        "restaurant_lakehouse.bronze.historical_orders"
    )
)

# %%
print("bronze.historical_orders created successfully")
# Out:
# bronze.historical_orders created successfully
