-- %%
%sql

SELECT order_id, COUNT(*) AS count
FROM restaurant_lakehouse.silver.fact_orders
GROUP BY order_id
HAVING COUNT(*) > 1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>count</th></tr></thead><tbody></tbody></table></div>

-- %%
%sql

SELECT customer_id, COUNT(*)
FROM restaurant_lakehouse.silver.dim_customer
GROUP BY customer_id
HAVING COUNT(*) > 1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>COUNT(*)</th></tr></thead><tbody></tbody></table></div>

-- %%
%sql

SELECT COUNT(*) AS orphan_orders
FROM restaurant_lakehouse.silver.fact_orders o

LEFT JOIN restaurant_lakehouse.silver.dim_customer c
    ON o.customer_id = c.customer_id

WHERE c.customer_id IS NULL;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>orphan_orders</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

-- %%
%sql

SELECT COUNT(*) AS orphan_restaurants
FROM restaurant_lakehouse.silver.fact_orders o

LEFT JOIN restaurant_lakehouse.silver.dim_restaurants r
    ON o.restaurant_id = r.restaurant_id

WHERE r.restaurant_id IS NULL;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>orphan_restaurants</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

-- %%
%sql

SELECT
    COUNT(*) AS total_orders,

    SUM(
        CASE WHEN customer_id IS NULL
        THEN 1 ELSE 0 END
    ) AS missing_customers,

    SUM(
        CASE WHEN restaurant_id IS NULL
        THEN 1 ELSE 0 END
    ) AS missing_restaurants,

    SUM(
        CASE WHEN total_amount IS NULL
        THEN 1 ELSE 0 END
    ) AS missing_amounts

FROM restaurant_lakehouse.silver.fact_orders;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_orders</th><th>missing_customers</th><th>missing_restaurants</th><th>missing_amounts</th></tr></thead><tbody><tr><td>8000</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

-- %%
%sql

SELECT *
FROM restaurant_lakehouse.silver.fact_reviews
WHERE rating < 1 OR rating > 5;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>review_id</th><th>order_id</th><th>customer_id</th><th>restaurant_id</th><th>review_text</th><th>rating</th><th>review_timestamp</th></tr></thead><tbody></tbody></table></div>
